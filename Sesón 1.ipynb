# %% [markdown]
# # Sesión 1 - Instalación de Python

# %% [markdown]
# Veremos como instalar python en nustras computadora, blah blah...
#  blah blah...
#
#
#      blah blah...
#
#          blah blah...
#
#              blah blah...
#
#                  blah blah...
#
#
#                      blah blah...

# %%
print('hola Mundo')
# Out:
# hola Mundo

# %% [markdown]
# Esta es  una suma dificil

# %%
3+4
# Out:
# 7

# %%
2 + 4 - 5
# Out:
# 1

# %% [markdown]
# Resuelvan la siguiente ecuación $x^2 + 3x+ 8\pi = 0$

# %% [markdown]
# # <span style= "color:darkblue"  > Puedo usar colores en mis códigos</span>

# %% [markdown]
# ##  <span style= "color:purple"  > Puedo usar colores en mis códigos</span>

# %% [markdown]
# ##  <span style= "color:red"  > Puedo usar colores en mis códigos</span>

# %% [markdown]
# ![Seso%CC%81n_1_-_Jupyter_Notebook.png](attachment:Seso%CC%81n_1_-_Jupyter_Notebook.png)
